# %%
import pandas as pd

# %%
salary=pd.DataFrame({'salary':[1000,50000,15000,2000],'cat':['little low','low','medium','high',]})

# %%
salary
# Out:
#    salary         cat
# 0    1000  little low
# 1   50000         low
# 2   15000      medium
# 3    2000        high

# %%
salary.cat
# Out:
# 0    little low
# 1           low
# 2        medium
# 3          high
# Name: cat, dtype: object

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as pt

# %%
# %matplotlib inline

# %%
GA=pd.read_csv("D:/Admission_Predict_Ver1.1 (1).csv")

# %%
GA
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1        337          118                  4  4.5  4.5  9.65
# 1             2        324          107                  4  4.0  4.5  8.87
# 2             3        316          104                  3  3.0  3.5  8.00
# 3             4        322          110                  3  3.5  2.5  8.67
# 4             5        314          103                  2  2.0  3.0  8.21
# ..          ...        ...          ...                ...  ...  ...   ...
# 495         496        332          108                  5  4.5  4.0  9.02
# 496         497        337          117                  5  5.0  5.0  9.87
# 497         498        330          120                  5  4.5  5.0  9.56
# 498         499        312          103                  4  4.0  5.0  8.43
# 499         500        327          113                  4  4.5  4.5  9.04
#
#      Research  Chance of Admit
# 0           1              0.92
# ...

# %%
laliga=GA.drop(['Serial No.','GRE Score','University Rating','SOP','LOR','CGPA','Research'],axis=1)

# %%
laliga
# Out:
#      TOEFL Score  Chance of Admit
# 0            118              0.92
# 1            107              0.76
# 2            104              0.72
# 3            110              0.80
# 4            103              0.65
# ..           ...               ...
# 495          108              0.87
# 496          117              0.96
# 497          120              0.93
# 498          103              0.73
# 499          113              0.84
#
# [500 rows x 2 columns]

# %%
GA.shape
# Out:
# (500, 9)

# %%
GA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         500 non-null    int64
#  1   GRE Score          500 non-null    int64
#  2   TOEFL Score        500 non-null    int64
#  3   University Rating  500 non-null    int64
#  4   SOP                500 non-null    float64
#  5   LOR                500 non-null    float64
#  6   CGPA               500 non-null    float64
#  7   Research           500 non-null    int64
#  8   Chance of Admit    500 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 35.3 KB

# %%
port=GA.drop(['Serial No.','GRE Score','University Rating','SOP','LOR','CGPA','Research'],axis=1)

# %%
port
# Out:
#      TOEFL Score  Chance of Admit
# 0            118              0.92
# 1            107              0.76
# 2            104              0.72
# 3            110              0.80
# 4            103              0.65
# ..           ...               ...
# 495          108              0.87
# 496          117              0.96
# 497          120              0.93
# 498          103              0.73
# 499          113              0.84
#
# [500 rows x 2 columns]

# %%
x=port.iloc[:,0].values.reshape(-1,1)
y=port.iloc[:,-1].values.reshape(-1,1)

# %%
y
# Out:
# array([[0.92],
#        [0.76],
#        [0.72],
#        [0.8 ],
#        [0.65],
#        [0.9 ],
#        [0.75],
#        [0.68],
#        [0.5 ],
#        [0.45],
#        [0.52],
#        [0.84],
#        [0.78],
#        [0.62],
#        [0.61],
#        [0.54],
#        [0.66],
#        [0.65],
#        [0.63],
#        [0.62],
#        [0.64],
#        [0.7 ],
#        [0.94],
#        [0.95],
#        [0.97],
#        [0.94],
#        [0.76],
#        [0.44],
#        [0.46],
#        [0.54],
#        [0.65],
#        [0.74],
#        [0.91],
#        [0.9 ],
#        [0.94],
#        [0.88],
#        [0.64],
#        [0.58],
#        [0.52],
#        [0.48],
#        [0.46],
#        [0.49],
#        [0.53],
#        [0.87],
#        [0.91],
#        [0.88],
#        [0.86],
#        [0.89],
#        [0.82],
#        [0.78],
#        [0.76],
#        [0.56],
#        [0.78],
#        [0.72],
#        [0.7 ],
#        [0.64],
#        [0.64],
#        [0.46],
# ...

# %%
pt.scatter(x,y)
pt.xlabel('gre score')
pt.ylabel('cha')
pt.title('linear reg')
pt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.5,random_state=0)

# %%
x_test.shape
# Out:
# (250, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %%
lm.fit
